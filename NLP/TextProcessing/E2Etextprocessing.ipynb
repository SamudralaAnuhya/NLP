# %% [markdown]
# textprocessing is the combination of
#
# tokenization (convert give text to sentence anf then to words)
# stopwords(remove stopwords from the above words )
# stemmer/lemmatization (will remove similar words and make it one which helps for doing classification
# )

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, SnowballStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
import nltk

# Ensure you have downloaded the necessary datasets
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

wordlemma = WordNetLemmatizer()

paragraph = '''
They say that at some point you just learn to let go, I must disagree. If it just takes one moment to let go, then you never really held on tightly enough. To a dream. To a goal. To a place. To a person. To anything. I believe you let go little by little. You let go a little, then hold back on, but with a little less force until you fully release yourself. And the tighter you hold on, the more force you let go with. The deeper you dive, the higher you'll fly. The closer you get, the further you'll pull away. The weaker you feel, the stronger you'll become. So do not be ashamed of your weaknesses. We all have them. You must learn to be kind to yourself. You must believe in yourself. You must learn to understand yourself. Never think that you are a bad person. Differentiate between your self-worth and your actions. To say that you are bad is different than saying that you made a mistake. You can't fix yourself, but you can fix a mistake.And remember, not one person on this earth is perfect. We all make mistakes. We all fall. We all have flaws. We just need to look within ourselves and treat ourselves as humans who are worthy of respect and hope. Do not give up on yourself . Get back up. Be brave. Be happy.” -Najwa Zebian
"I look around at us and you know what I see? Losers. I mean, like, folks who have lost stuff. And we have, man, we have, all of us. Homes, and our families, normal lives. And you think life takes more than it gives, but not today. Today it's giving us something. It is giving us a chance." Guardians of the Galaxy
“There's no such thing as too far. You understand? You push everything as far as you can. You push and you push and you push until it starts pushing back. And then you push some goddamn more.”- Two for the Money
'''

sentences = sent_tokenize(paragraph)

for i in range(len(sentences)):
    # Convert sentence to words
    words = word_tokenize(sentences[i])
    words = [wordlemma.lemmatize(word, pos='v') for word in words if word.lower() not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)


sentences
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anuhyasamudrala/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anuhyasamudrala/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/anuhyasamudrala/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['say point learn let go , must disagree .',
#  'take one moment let go , never really hold tightly enough .',
#  'dream .',
#  'goal .',
#  'place .',
#  'person .',
#  'anything .',
#  'believe let go little little .',
#  'let go little , hold back , little less force fully release .',
#  'tighter hold , force let go .',
#  "deeper dive , higher 'll fly .",
#  "closer get , 'll pull away .",
#  "weaker feel , stronger 'll become .",
#  'ashamed weaknesses .',
#  '.',
#  'must learn kind .',
#  'must believe .',
#  'must learn understand .',
#  'Never think bad person .',
#  'Differentiate self-worth action .',
#  'say bad different say make mistake .',
#  "ca n't fix , fix mistake.And remember , one person earth perfect .",
#  'make mistake .',
#  'fall .',
#  'flaw .',
#  'need look within treat humans worthy respect hope .',
#  'give .',
#  'Get back .',
#  'brave .',
#  "happy. ” -Najwa Zebian '' look around us know see ?",
#  'Losers .',
#  'mean , like , folks lose stuff .',
#  ', man , , us .',
#  'Homes , families , normal live .',
#  'think life take give , today .',
#  "Today 's give us something .",
#  "give us chance . ''",
#  "Guardians Galaxy “ 's thing far .",
#  'understand ?',
#  'push everything far .',
#  'push push push start push back .',
#  'push goddamn more. ” - Two Money']

# %%
#postag  in lemmatizer there will pos which is like pos = v (verb) , pos = n(noun)\
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, SnowballStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
import nltk


wordlemma = WordNetLemmatizer()

paragraph = '''
They say that at some point you just learn to let go, I must disagree. If it just takes one moment to let go, then you never really held on tightly enough. To a dream. To a goal. To a place. To a person. To anything. I believe you let go little by little. You let go a little, then hold back on, but with a little less force until you fully release yourself. And the tighter you hold on, the more force you let go with. The deeper you dive, the higher you'll fly. The closer you get, the further you'll pull away. The weaker you feel, the stronger you'll become. So do not be ashamed of your weaknesses. We all have them. You must learn to be kind to yourself. You must believe in yourself. You must learn to understand yourself. Never think that you are a bad person. Differentiate between your self-worth and your actions. To say that you are bad is different than saying that you made a mistake. You can't fix yourself, but you can fix a mistake.And remember, not one person on this earth is perfect. We all make mistakes. We all fall. We all have flaws. We just need to look within ourselves and treat ourselves as humans who are worthy of respect and hope. Do not give up on yourself . Get back up. Be brave. Be happy.” -Najwa Zebian
"I look around at us and you know what I see? Losers. I mean, like, folks who have lost stuff. And we have, man, we have, all of us. Homes, and our families, normal lives. And you think life takes more than it gives, but not today. Today it's giving us something. It is giving us a chance." Guardians of the Galaxy
“There's no such thing as too far. You understand? You push everything as far as you can. You push and you push and you push until it starts pushing back. And then you push some goddamn more.”- Two for the Money
'''

sentences = sent_tokenize(paragraph)

for i in range(len(sentences)):
    # Convert sentence to words
    words = word_tokenize(sentences[i])
    words = [word for word in words if word.lower() not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('say', 'VB'), ('point', 'NN'), ('learn', 'JJ'), ('let', 'NN'), ('go', 'VB'), (',', ','), ('must', 'MD'), ('disagree', 'VB'), ('.', '.')]
# [('takes', 'VBZ'), ('one', 'CD'), ('moment', 'NN'), ('let', 'NN'), ('go', 'VB'), (',', ','), ('never', 'RB'), ('really', 'RB'), ('held', 'VBN'), ('tightly', 'RB'), ('enough', 'RB'), ('.', '.')]
# [('dream', 'NN'), ('.', '.')]
# [('goal', 'NN'), ('.', '.')]
# [('place', 'NN'), ('.', '.')]
# [('person', 'NN'), ('.', '.')]
# [('anything', 'NN'), ('.', '.')]
# [('believe', 'VB'), ('let', 'NN'), ('go', 'VB'), ('little', 'JJ'), ('little', 'JJ'), ('.', '.')]
# [('let', 'VB'), ('go', 'VB'), ('little', 'JJ'), (',', ','), ('hold', 'VB'), ('back', 'RP'), (',', ','), ('little', 'RB'), ('less', 'JJR'), ('force', 'NN'), ('fully', 'RB'), ('release', 'NN'), ('.', '.')]
# [('tighter', 'NN'), ('hold', 'NN'), (',', ','), ('force', 'NN'), ('let', 'NN'), ('go', 'VB'), ('.', '.')]
# [('deeper', 'RBR'), ('dive', 'NN'), (',', ','), ('higher', 'JJR'), ("'ll", 'MD'), ('fly', 'VB'), ('.', '.')]
# [('closer', 'RBR'), ('get', 'NN'), (',', ','), ("'ll", 'MD'), ('pull', 'VB'), ('away', 'RB'), ('.', '.')]
# [('weaker', 'NN'), ('feel', 'NN'), (',', ','), ('stronger', 'JJR'), ("'ll", 'MD'), ('become', 'VB'), ('.', '.')]
# [('ashamed', 'JJ'), ('weaknesses', 'NNS'), ('.', '.')]
# [('.', '.')]
# [('must', 'MD'), ('learn', 'VB'), ('kind', 'NN'), ('.', '.')]
# [('must', 'MD'), ('believe', 'VB'), ('.', '.')]
# [('must', 'MD'), ('learn', 'VB'), ('understand', 'NN'), ('.', '.')]
# [('Never', 'RB'), ('think', 'VBP'), ('bad', 'JJ'), ('person', 'NN'), ('.', '.')]
# [('Differentiate', 'NNP'), ('self-worth', 'JJ'), ('actions', 'NNS'), ('.', '.')]
# [('say', 'VB'), ('bad', 'JJ'), ('different', 'JJ'), ('saying', 'VBG'), ('made', 'VBN'), ('mistake', 'NN'), ('.', '.')]
# [('ca', 'MD'), ("n't", 'RB'), ('fix', 'VB'), (',', ','), ('fix', 'VB'), ('mistake.And', 'JJ'), ('remember', 'NN'), (',', ','), ('one', 'CD'), ('person', 'NN'), ('earth', 'NN'), ('perfect', 'NN'), ('.', '.')]
# [('make', 'NN'), ('mistakes', 'NNS'), ('.', '.')]
# [('fall', 'NN'), ('.', '.')]
# [('flaws', 'NNS'), ('.', '.')]
# [('need', 'NN'), ('look', 'NN'), ('within', 'IN'), ('treat', 'NN'), ('humans', 'NNS'), ('worthy', 'JJ'), ('respect', 'VBP'), ('hope', 'NN'), ('.', '.')]
# [('give', 'NN'), ('.', '.')]
# [('Get', 'NNP'), ('back', 'RB'), ('.', '.')]
# [('brave', 'NN'), ('.', '.')]
# [('happy.', 'NN'), ('”', 'NNP'), ('-Najwa', 'NNP'), ('Zebian', 'NNP'), ("''", "''"), ('look', 'NN'), ('around', 'IN'), ('us', 'PRP'), ('know', 'VBP'), ('see', 'VB'), ('?', '.')]
# [('Losers', 'NNS'), ('.', '.')]
# [('mean', 'NN'), (',', ','), ('like', 'IN'), (',', ','), ('folks', 'NNS'), ('lost', 'VBD'), ('stuff', 'NN'), ('.', '.')]
# [(',', ','), ('man', 'NN'), (',', ','), (',', ','), ('us', 'PRP'), ('.', '.')]
# [('Homes', 'NNS'), (',', ','), ('families', 'NNS'), (',', ','), ('normal', 'JJ'), ('lives', 'NNS'), ('.', '.')]
# [('think', 'VB'), ('life', 'NN'), ('takes', 'VBZ'), ('gives', 'VBZ'), (',', ','), ('today', 'NN'), ('.', '.')]
# [('Today', 'NN'), ("'s", 'POS'), ('giving', 'VBG'), ('us', 'PRP'), ('something', 'NN'), ('.', '.')]
# [('giving', 'VBG'), ('us', 'PRP'), ('chance', 'NN'), ('.', '.'), ("''", "''")]
# [('Guardians', 'NNS'), ('Galaxy', 'NNP'), ('“', 'NNP'), ("'s", 'POS'), ('thing', 'NN'), ('far', 'RB'), ('.', '.')]
# [('understand', 'NN'), ('?', '.')]
# [('push', 'NN'), ('everything', 'NN'), ('far', 'RB'), ('.', '.')]
# [('push', 'NN'), ('push', 'NN'), ('push', 'NN'), ('starts', 'VBZ'), ('pushing', 'VBG'), ('back', 'RP'), ('.', '.')]
# [('push', 'NN'), ('goddamn', 'NN'), ('more.', 'NN'), ('”', 'SYM'), ('-', ':'), ('Two', 'CD'), ('Money', 'NN')]

# %% [markdown]
# #### parts of speech tagging

# %%
###parts of speech tagging

paragraph = '''
They say that at some point you just learn to let go, I must disagree. If it just takes one moment to let go, then you never really held on tightly enough. To a dream. To a goal. To a place. To a person. To anything. I believe you let go little by little. You let go a little, then hold back on, but with a little less force until you fully release yourself. And the tighter you hold on, the more force you let go with. The deeper you dive, the higher you'll fly. The closer you get, the further you'll pull away. The weaker you feel, the stronger you'll become. So do not be ashamed of your weaknesses. We all have them. You must learn to be kind to yourself. You must believe in yourself. You must learn to understand yourself. Never think that you are a bad person. Differentiate between your self-worth and your actions. To say that you are bad is different than saying that you made a mistake. You can't fix yourself, but you can fix a mistake.And remember, not one person on this earth is perfect. We all make mistakes. We all fall. We all have flaws. We just need to look within ourselves and treat ourselves as humans who are worthy of respect and hope. Do not give up on yourself . Get back up. Be brave. Be happy.” -Najwa Zebian
"I look around at us and you know what I see? Losers. I mean, like, folks who have lost stuff. And we have, man, we have, all of us. Homes, and our families, normal lives. And you think life takes more than it gives, but not today. Today it's giving us something. It is giving us a chance." Guardians of the Galaxy
“There's no such thing as too far. You understand? You push everything as far as you can. You push and you push and you push until it starts pushing back. And then you push some goddamn more.”- Two for the Money
'''

words = nltk.word_tokenize(paragraph)
pos_tag=nltk.pos_tag(words)
nltk.ne_chunk(pos_tag)
# Out:
# Tree('S', [('They', 'PRP'), ('say', 'VBP'), ('that', 'IN'), ('at', 'IN'), ('some', 'DT'), ('point', 'NN'), ('you', 'PRP'), ('just', 'RB'), ('learn', 'VB'), ('to', 'TO'), ('let', 'VB'), ('go', 'VB'), (',', ','), ('I', 'PRP'), ('must', 'MD'), ('disagree', 'VB'), ('.', '.'), ('If', 'IN'), ('it', 'PRP'), ('just', 'RB'), ('takes', 'VBZ'), ('one', 'CD'), ('moment', 'NN'), ('to', 'TO'), ('let', 'VB'), ('go', 'VB'), (',', ','), ('then', 'RB'), ('you', 'PRP'), ('never', 'RB'), ('really', 'RB'), ('held', 'VBN'), ('on', 'IN'), ('tightly', 'RB'), ('enough', 'RB'), ('.', '.'), ('To', 'TO'), ('a', 'DT'), ('dream', 'NN'), ('.', '.'), ('To', 'TO'), ('a', 'DT'), ('goal', 'NN'), ('.', '.'), ('To', 'TO'), ('a', 'DT'), ('place', 'NN'), ('.', '.'), ('To', 'TO'), ('a', 'DT'), ('person', 'NN'), ('.', '.'), ('To', 'TO'), ('anything', 'NN'), ('.', '.'), ('I', 'PRP'), ('believe', 'VBP'), ('you', 'PRP'), ('let', 'VB'), ('go', 'VB'), ('little', 'JJ'), ('by', 'IN'), ('little', 'JJ'), ('.', '.'), ('You', 'PRP'), ('let', 'VBP'), ('go', 'VB'), ('a', 'DT'), ('little', 'RB'), (',', ','), ('then', 'RB'), ('hold', 'VB'), ('back', 'RB'), ('on', 'IN'), (',', ','), ('but', 'CC'), ('with', 'IN'), ('a', 'DT'), ('little', 'JJ'), ('less', 'JJR'), ('force', 'NN'), ('until', 'IN'), ('you', 'PRP'), ('fully', 'RB'), ('release', 'VB'), ('yourself', 'PRP'), ('.', '.'), ('And', 'CC'), ('the', 'DT'), ('tighter', 'NN'), ('you', 'PRP'), ('hold', 'VBP'), ('on', 'IN'), (',', ','), ('the', 'DT'), ('more', 'JJR'), ('force', 'NN'), ('you', 'PRP'), ('let', 'VBP'), ('go', 'VB'), ('with', 'IN'), ('.', '.'), ('The', 'DT'), ('deeper', 'JJR'), ('you', 'PRP'), ('dive', 'VBP'), (',', ','), ('the', 'DT'), ('higher', 'JJR'), ('you', 'PRP'), ("'ll", 'MD'), ('fly', 'VB'), ('.', '.'), ('The', 'DT'), ('closer', 'NN'), ('you', 'PRP'), ('get', 'VBP'), (',', ','), ('the', 'DT'), ('further', 'RB'), ('you', 'PRP'), ("'ll", 'MD'), ('pull', 'VB'), ('away', 'RB'), ('.', '.'), ('The', 'DT'), ('weaker', 'JJR'), ('you', 'PRP'), ('feel', 'VBP'), (',', ','), ('the', 'DT'), ('stronger', 'JJR'), ('you', 'PRP'), ("'ll", 'MD'), ('become', 'VB'), ('.', '.'), ('So', 'RB'), ('do', 'JJ'), ('not', 'RB'), ('be', 'VB'), ('ashamed', 'VBN'), ('of', 'IN'), ('your', 'PRP$'), ('weaknesses', 'NNS'), ('.', '.'), ('We', 'PRP'), ('all', 'DT'), ('have', 'VBP'), ('them', 'PRP'), ('.', '.'), ('You', 'PRP'), ('must', 'MD'), ('learn', 'VB'), ('to', 'TO'), ('be', 'VB'), ('kind', 'NN'), ('to', 'TO'), ('yourself', 'PRP'), ('.', '.'), ('You', 'PRP'), ('must', 'MD'), ('believe', 'VB'), ('in', 'IN'), ('yourself', 'PRP'), ('.', '.'), ('You', 'PRP'), ('must', 'MD'), ('learn', 'VB'), ('to', 'TO'), ('understand', 'VB'), ('yourself', 'PRP'), ('.', '.'), ('Never', 'RB'), ('think', 'VBP'), ('that', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('a', 'DT'), ('bad', 'JJ'), ('person', 'NN'), ('.', '.'), ('Differentiate', 'NNP'), ('between', 'IN'), ('your', 'PRP$'), ('self-worth', 'JJ'), ('and', 'CC'), ('your', 'PRP$'), ('actions', 'NNS'), ('.', '.'), ('To', 'TO'), ('say', 'VB'), ('that', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('bad', 'JJ'), ('is', 'VBZ'), ('different', 'JJ'), ('than', 'IN'), ('saying', 'VBG'), ('that', 'IN'), ('you', 'PRP'), ('made', 'VBD'), ('a', 'DT'), ('mistake', 'NN'), ('.', '.'), ('You', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), ('fix', 'VB'), ('yourself', 'PRP'), (',', ','), ('but', 'CC'), ('you', 'PRP'), ('can', 'MD'), ('fix', 'VB'), ('a', 'DT'), ('mistake.And', 'JJ'), ('remember', 'NN'), (',', ','), ('not', 'RB'), ('one', 'CD'), ('person', 'NN'), ('on', 'IN'), ('this', 'DT'), ('earth', 'NN'), ('is', 'VBZ'), ('perfect', 'JJ'), ('.', '.'), ('We', 'PRP'), ('all', 'DT'), ('make', 'VBP'), ('mistakes', 'NNS'), ('.', '.'), ('We', 'PRP'), ('all', 'DT'), ('fall', 'NN'), ('.', '.'), ('We', 'PRP'), ('all', 'DT'), ('have', 'VBP'), ('flaws', 'NNS'), ('.', '.'), ('We', 'PRP'), ('just', 'RB'), ('need', 'VBP'), ('to', 'TO'), ('look', 'VB'), ('within', 'IN'), ('ourselves', 'PRP'), ('and', 'CC'), ('treat', 'VB'), ('ourselves', 'PRP'), ('as', 'IN'), ('huma ...

# %%
# !pip install svgling
# Out:
# Collecting svgling
#   Downloading svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading svgling-0.5.0-py3-none-any.whl (31 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.5.0 svgwrite-1.4.3
